# %% [markdown]
# ## About Dataset
# This dataset was collected via Python scraper in March 2023 and contains:
#
# information about all beauty products (over 8,000) from the Sephora online store, including product and brand names, prices, ingredients, ratings, and all features.
# user reviews (about 1 million on over 2,000 products) of all products from the Skincare category, including user appearances, and review ratings by other users

# %% [markdown]
# # 💼 Business Use Case: Product Pricing & Rating Optimization
# 🧠 Goal:
# Help Sephora (or a competitor) identify which product features, brands, or categories are associated with higher customer ratings and higher prices, in order to:
#
# Optimize product pricing strategies
#
# Curate high-performing product selections
#
# Understand what customers value most (e.g., ingredients, brand prestige, packaging features)

# %%
# import pandas as pd

product_info=pd.read_csv(r"C:\Users\soumy\Downloads\archive (29)\product_info.csv", delimiter=',')
product_info.head()

product_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8494 entries, 0 to 8493
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   product_id          8494 non-null   object
#  1   product_name        8494 non-null   object
#  2   brand_id            8494 non-null   int64
#  3   brand_name          8494 non-null   object
#  4   loves_count         8494 non-null   int64
#  5   rating              8216 non-null   float64
#  6   reviews             8216 non-null   float64
#  7   size                6863 non-null   object
#  8   variation_type      7050 non-null   object
#  9   variation_value     6896 non-null   object
#  10  variation_desc      1250 non-null   object
#  11  ingredients         7549 non-null   object
#  12  price_usd           8494 non-null   float64
#  13  value_price_usd     451 non-null    float64
#  14  sale_price_usd      270 non-null    float64
#  15  limited_edition     8494 non-null   int64
#  16  new                 8494 non-null   int64
#  17  online_only         8494 non-null   int64
#  18  out_of_stock        8494 non-null   int64
#  19  sephora_exclusive   8494 non-null   int64
#  20  highlights          6287 non-null   object
#  21  primary_category    8494 non-null   object
#  22  secondary_category  8486 non-null   object
#  23  tertiary_category   7504 non-null   object
#  24  child_count         8494 non-null   int64
#  25  child_max_price     2754 non-null   float64
#  26  child_min_price     2754 non-null   float64
# dtypes: float64(7), int64(8), object(12)
# memory usage: 1.7+ MB

# %% [markdown]
# metric details:
# The 'Child count' is just a measure of how many options a given product has. For example, a product can have:
# 6 different colors (child count = 6)
# 3 different sizes small/medium/large (child count = 3)
# 3 different sizes and 6 color options each (child count = 18)

# %%
#total products across 8000 Sephora Store
product_info['product_id'].nunique()
# Out:
# 8494

# %%
#total brands
product_info['brand_id'].nunique()
# Out:
# 304

# %%
#total primary categories
product_info['primary_category'].nunique()
# Out:
# 9

# %%
#total secondary categories in each primary categories
product_info.groupby('primary_category')['secondary_category'].nunique().sort_values()
# Out:
# primary_category
# Gifts               0
# Tools & Brushes     4
# Fragrance           5
# Men                 5
# Hair                6
# Mini Size           6
# Bath & Body         9
# Makeup             10
# Skincare           13
# Name: secondary_category, dtype: int64

# %%
#Overview of categories
product_info.groupby(['primary_category', 'secondary_category','tertiary_category']).size()
#.reset_index(name='count').head(134)


#products with more than 4.5 rating
product_info[product_info['rating'] >= 4.5].sort_values(by='price_usd', ascending=False)
# Out:
#      product_id                            product_name  brand_id  \
# 4313    P461949                   The Concentrate Serum      6201
# 6799    P471097                   Facial Sculpting Wand      6314
# 5555    P504221                    Trinity+ Starter Kit      6001
# 7821    P501479                Bitter Peach Perfume Set      5869
# 7803    P501561                 Lost Cherry Perfume Set      5869
# ...         ...                                     ...       ...
# 6685    P473724                           Vitamin Tonic      3902
# 6719    P502481                      Lip Gloss Ornament      3902
# 6720    P461200         Clean Watermelon After Sun Mask      3902
# 6579    P467138          Beauty on the Fly Reusable Bag      3902
# 4717    P421291  Artist Color Refillable Makeup Palette      4028
#
#                   brand_name  loves_count  rating  reviews             size  \
# 4313                  La Mer         7514  4.5187    563.0      1 oz/ 30 mL
# 6799  Shani Darden Skin Care         7753  4.5462    130.0              NaN
# 5555                  NuFACE         1085  5.0000      2.0              NaN
# 7821                TOM FORD         3644  4.6667      3.0              NaN
# 7803                TOM FORD         6342  5.0000      3.0              NaN
# ...                      ...          ...     ...      ...              ...
# 6685      SEPHORA COLLECTION        12475  4.6875     48.0  3.38 oz/ 100 mL
# 6719      SEPHORA COLLECTION         3899  5.0000      2.0  0.16 oz / 4.8 g
# 6720      SEPHORA COLLECTION         9000  4.6667     27.0           1 Mask
# 6579      SEPHORA COLLECTION        16473  4.7000     60.0              NaN
# 4717        MAKE UP FOR EVER        57439  4.7300    263.0              NaN
#
#      variation_type variation_value  ... online_only out_of_stock  \
# 4313           Size     1 oz/ 30 mL  ...           0            0
# 6799            NaN             NaN  ...           1            0
# 5555            NaN             NaN  ...           0            0
# 7821            NaN             NaN  ...           0            0
# 7803            NaN             NaN  ...           0            0
# ...             ...             ...  ...         ...          ...
# 6685           Type        Cucumber  ...           0            0
# 6719            NaN             NaN  ...           0            1
# 6720           Size          1 Mask  ...           0            0
# 6579            NaN             NaN  ...           0            0
# 4717           Type           Large  ...           0            0
#
#       sephora_exclusive                                         highlights  \
# 4313                  0  ['Without Phthalates', 'Good for: Dryness', 'W...
# 6799                  1  ['Vegan', 'Hyaluronic Acid', 'Good for: Loss o...
# 5555                  1  ['allure 2022 Best of Beauty Award Winner', 'H...
# 7821                  0  ['Unisex/ Genderless Scent', 'Layerable Scent'...
# 7803                  0  ['Unisex/ Genderless Scent', 'Layerable Scent'...
# ...                 ...                                                ...
# 6685                  1  ['Best for Dry, Combo, Normal Skin', 'Good for...
# 6719                  1                ['Cream Formula', 'Shimmer Finish']
# 6720                  1                      ['Vegan', 'Clean at Sephora']
# 6579                  1                                                NaN
# 4717                  1                                                NaN
#
#       primary_category  secondary_category      tertiary_category  \
# 4313          Skincare          Treatments            Face Serums
# 6799          Skincare     High Tech Tools             Anti-Aging
# 5555          Skincare     High Tech Tools             Anti-Aging
# 7821         Fragrance   Value & Gift Sets      Perfume Gift Sets
# 7803         Fragrance   Value & Gift Sets      Perfume Gift Sets
# ...                ...                 ...                    ...
# 6685          Skincare           Cleansers                 Toners
# 6719            Makeup   Value & Gift Sets                    NaN
# 6720          Skincare               Masks            Sheet Masks
# 6579   Tools & Brushes  Beauty Accessories  Makeup & Travel Cases
# 4717            Makeup     Makeup Palettes                    NaN
#
#       child_count  child_max_price  child_min_price
# 4313            1            220.0            220.0
# 6799            0              NaN              NaN
# 5555            0              NaN              NaN
# 7821            0              NaN              NaN
# 7803            0              NaN              NaN
# ...           ...              ...              ...
# 6685            0              NaN              NaN
# 6719            0              NaN              NaN
# 6720            0              NaN              NaN
# 6579            0              NaN              NaN
# 4717            4              4.0              4.0
#
# [2375 rows x 27 columns]
